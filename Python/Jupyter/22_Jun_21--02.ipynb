# %%
myNRIC="031101-13-1301"

# %%
myIC=input("Enter your IC numbers :")

# %%
myIC
# Out:
# '030512-13-0974'

# %%
myIC[0]+myIC[-1]
# Out:
# '04'

# %%
studID="21UHF03040"

# %%
str(studID[0:2])+str(studID[5:10])
# Out:
# '2103040'

# %%
import math

#To calculate the circumference of a circle

radius=input("Enter radius :")

orbit=2*(3.14159)*float(radius)

actual_orbit=2*math.pi*float(radius)

print("Distance travelled is ",orbit)

print("Actual distance travelled is ",actual_orbit)
# Out:
# Distance travelled is  140.114914
# Actual distance travelled is  140.11503235010477
