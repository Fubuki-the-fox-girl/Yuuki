# %%
15+1
# Out:
# 16

# %%
15.0-1
# Out:
# 14.0

# %%
"15"+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17400/3722263836.py in <module>
# ----> 1 "15"+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
15*2
# Out:
# 30

# %%
15/2
# Out:
# 7.5

# %%
15//2
# Out:
# 7

# %%
-15//2
# Out:
# -8

# %%
5%2
# Out:
# 1

# %%
(-5)%2
# Out:
# 1

# %%
5%(-2)
# Out:
# -1

# %%
 4**(1/2)
# Out:
# 2.0

# %%
4**(1/3)
# Out:
# 1.5874010519681994

# %%
import math

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
y=5.235

# %%
x=y+5

# %%
x
# Out:
# 10.235

# %%
z=3

# %%
z+=3

# %%
z
# Out:
# 6

# %%
z+=4

# %%
z
# Out:
# 10

# %%
z+=5

# %%
z
# Out:
# 15

# %%
#------------

# %%
0==0
# Out:
# True

# %%
0>0
# Out:
# False

# %%
0<5
# Out:
# True

# %%
0>=0
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
1>0 and 5>1
# Out:
# True

# %%
#--------

# %%
round(2.5)
# Out:
# 2

# %%
round(2.51)
# Out:
# 3

# %%
round(-2.51)
# Out:
# -3

# %%
round(-2.5)
# Out:
# -2

# %%
int(-2.51)
# Out:
# -2

# %%
int(-2.91)
# Out:
# -2

# %%
int(-3.01)
# Out:
# -3

# %%
int(3.01)
# Out:
# 3
