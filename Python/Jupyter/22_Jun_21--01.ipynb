# %%
15
# Out:
# 15

# %%
id(15)
# Out:
# 1971056700144

# %%
type(15)
# Out:
# int

# %%
myInt=15

# %%
type(myInt)
# Out:
# int

# %%
id(myInt)
# Out:
# 1971056700144

# %%
"abc"
# Out:
# 'abc'

# %%
id("abc")
# Out:
# 1971063743664

# %%
myStr="abc"

# %%
type(myStr)
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
myList=[12,12,1]

# %%
type(myList)
# Out:
# list

# %%
myTuple=(15,12,1)

# %%
type(myTuple)
# Out:
# tuple

# %%
myDict={"name":"Gura","age":9243}

# %%
type(myDict)
# Out:
# dict

# %%
myList=[3.14249,12730,"gura"]

# %%
myList[0]
# Out:
# 3.14249

# %%
myList[1]
# Out:
# 12730

# %%
myList[2]
# Out:
# 'gura'

# %%
myList[2][0]
# Out:
# 'g'

# %%
str(myList[0])[0]
# Out:
# '3'

# %%
int(myList[0])
# Out:
# 3

# %%
type(myList)
# Out:
# list

# %%
List=[2,3,5,7,9,1,33,21]

# %%
List[2:5]
# Out:
# [5, 7, 9]

# %%
List[5:-7]
# Out:
# []

# %%
List[5]
# Out:
# 1

# %%
List[-8]
# Out:
# 2

# %%
List[-8:-6]
# Out:
# [2, 3]

# %%
List[:7]
# Out:
# [2, 3, 5, 7, 9, 1, 33]

# %%
List[2:]
# Out:
# [5, 7, 9, 1, 33, 21]
